# %%
import numpy

# %%
x = 30
bin(x)
# Out:
# '0b11110'

# %%
y = 19
bin(y)
# Out:
# '0b10011'

# %%
bin(x+y)
# Out:
# '0b110001'

# %%
x+y
# Out:
# 49

# %%
def add(x, y):
    for i in range(32):
#       & = AND gate
        a = x & y
#       print(a)
#       ^ = XOR
        b = x ^ y
#         print("before",a)
#         print("before",bin(a))
#       bitwise rightshift
        x = a << 1
#         print("after",x)
#         print("after",bin(x))
        y = b
    return b

# %%
add(x,y)
# Out:
# 49

# %%
bin(add(x,y))
# Out:
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# ...

# %%
for i in range(20) :
    print(bin(x))
    x = x << 1
    
print(x)
# Out:
# 0b11110
# 0b111100
# 0b1111000
# 0b11110000
# 0b111100000
# 0b1111000000
# 0b11110000000
# 0b111100000000
# 0b1111000000000
# 0b11110000000000
# 0b111100000000000
# 0b1111000000000000
# 0b11110000000000000
# 0b111100000000000000
# 0b1111000000000000000
# 0b11110000000000000000
# 0b111100000000000000000
# 0b1111000000000000000000
# 0b11110000000000000000000
# 0b111100000000000000000000
# 31457280

# %%
for i in range(20) :
    i = i**20
    for j in range(20) :
        j = j**40
        assert (add(i,j) == (i+j))
        print("i : ",i, ", j :",j )
        print("bit add : ",add(i,j), ", ref add :",(i+j) )
# Out:
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# after 0b0
# before 0
# before 0b0
# after 0
# ...
